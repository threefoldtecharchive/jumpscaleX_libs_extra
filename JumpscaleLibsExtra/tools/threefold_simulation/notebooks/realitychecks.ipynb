# %% [markdown]
# # Reality Checks

# %%
#will also do the simulation calculation, takes time
from lib import *
simulation = j.tools.tfgrid_simulator.simulation_get(
            name="default",
            tokencreator_name="optimized",
        )
server=simulation.environment.node_normalized
md_code("params/default.py")
startmonth = 1

# %%
md(f"""
## Simulation Arguments 

- nr of nodes at start: {simulation.nodebatches[0].nrnodes}
- nr of months left (avg out) for farming of startingnodes: {simulation.nodebatches[0].months_left}
- nr of TFT already farmed: { j.data.types.numeric.clean(simulation.nodebatches[0].tft_farmed_before_simulation)} 

""")
# Out:
# ## Simulation Arguments
#
# - nr of nodes at start: 1500
# - nr of months left (avg out) for farming of startingnodes: 36
# - nr of TFT already farmed: 800,000,000

# %% [markdown]
# ## Device Details

# %%
md(simulation.markdown_reality_check(1))
# Out:
# ![](https://lh3.googleusercontent.com/ueuxCFqv1SvuR9HdR8GGz4-S8cJ8Z_do62mq7xaFVDgi31JCbPE5Hqjr7_ChvmXcgsrBuXZEYoX0Cv02iMe5yJfb_e-0-moQIrI=s1000)
# ## Some Totals for the simulation: (1 month mark)
#
# - nrnodes: 1529
# - nrtokens cultivated: 158,721
# - tft price: 0.2 USD
# - USD cultivated in that month: 31,744 USD
# - USD farmed in that month: 415,498 USD
#
# ### simulation params in this month
#
# - utilization           : 0.04
# - price decline         : 0.01
# - cu price              : 14
# - su price              : 9
# - nu price              : 0.05
#
# ### cloud units sold total
#
# - #cu        : 969
# - #su        : 1,723
# - #nu        : 78k
#
# ### per node production
#
# #### per node setup
#
# - USD investment cost per node: 2,351
#
# #### cloud units per node
#
# - #cu               : 15
# - #su               : 28
# - #nu               : 1,277
# - cost of 1 nu      : 0.01
# - passmark per cu   : 880
#
# #### resource units per node
#
# - cpr : 51
# - cru : 16
# - sru : 1,920
# - hru : 24k
# - mru : 64
#
# #### revenue per month per node based on simulation totals
#
# - rev compute month         : 8.4
# - rev storage month         : 10
# - rev network month         : 2.3
# - rev total month           : 20
#
# #### costs per month per node normalized over months
#
# - cost hardware month       : 39
# - cost rack month           : 60
# - cost power month          : 1.6
# - cost maintenance month    : 3.9
# - cost network month        : 0.65
#
# #### costs per month per node based on simulation totals
#
# - cost hardware month       : 39
# - cost rack month           : 60
# - cost power month          : 8.2
# - cost maintenance month    : 3.9
# - cost network month        : 3.2
# - cost total month          : 114
# - cost total month no hw    : 75
#
# ### per node per month
#
# - USD cultivated per node                                   :  20.8 USD
# - USD farmed per node                                       :  271 USD
# - USD burned per node                                       :  0 USD
# - USD monthly tft sold (rackspace/power/mgmt/net)           :  75 USD
# - USD monthly cost per node (rackspace/power/mgmt/net)      :  75 USD
# - USD profit for farmer per node (profit from token income) :  217 USD

# %%
md(simulation.markdown_reality_check(10))
# Out:
# ![](https://lh3.googleusercontent.com/ueuxCFqv1SvuR9HdR8GGz4-S8cJ8Z_do62mq7xaFVDgi31JCbPE5Hqjr7_ChvmXcgsrBuXZEYoX0Cv02iMe5yJfb_e-0-moQIrI=s1000)
# ## Some Totals for the simulation: (10 month mark)
#
# - nrnodes: 4054
# - nrtokens cultivated: 1,299,777
# - tft price: 0.63 USD
# - USD cultivated in that month: 818,859 USD
# - USD farmed in that month: 1,132,036 USD
#
# ### simulation params in this month
#
# - utilization           : 0.4
# - price decline         : 0.07
# - cu price              : 14
# - su price              : 9
# - nu price              : 0.05
#
# ### cloud units sold total
#
# - #cu        : 27k
# - #su        : 48k
# - #nu        : 2,070k
#
# ### per node production
#
# #### per node setup
#
# - USD investment cost per node: 2,351
#
# #### cloud units per node
#
# - #cu               : 16
# - #su               : 29
# - #nu               : 1,277
# - cost of 1 nu      : 0.01
# - passmark per cu   : 880
#
# #### resource units per node
#
# - cpr : 51
# - cru : 16
# - sru : 1,920
# - hru : 24k
# - mru : 64
#
# #### revenue per month per node based on simulation totals
#
# - rev compute month         : 81
# - rev storage month         : 97
# - rev network month         : 22
# - rev total month           : 201
#
# #### costs per month per node normalized over months
#
# - cost hardware month       : 39
# - cost rack month           : 60
# - cost power month          : 16
# - cost maintenance month    : 3.9
# - cost network month        : 6.5
#
# #### costs per month per node based on simulation totals
#
# - cost hardware month       : 39
# - cost rack month           : 59
# - cost power month          : 19
# - cost maintenance month    : 3.9
# - cost network month        : 7.7
# - cost total month          : 130
# - cost total month no hw    : 91
#
# ### per node per month
#
# - USD cultivated per node                                   :  201 USD
# - USD farmed per node                                       :  279 USD
# - USD burned per node                                       :  0 USD
# - USD monthly tft sold (rackspace/power/mgmt/net)           :  91 USD
# - USD monthly cost per node (rackspace/power/mgmt/net)      :  91 USD
# - USD profit for farmer per node (profit from token income) :  389 USD

# %%
md(simulation.markdown_reality_check(20))
# Out:
# ![](https://lh3.googleusercontent.com/ueuxCFqv1SvuR9HdR8GGz4-S8cJ8Z_do62mq7xaFVDgi31JCbPE5Hqjr7_ChvmXcgsrBuXZEYoX0Cv02iMe5yJfb_e-0-moQIrI=s1000)
# ## Some Totals for the simulation: (20 month mark)
#
# - nrnodes: 44412
# - nrtokens cultivated: 16,107,193
# - tft price: 1.11 USD
# - USD cultivated in that month: 17,878,984 USD
# - USD farmed in that month: 13,096,497 USD
#
# ### simulation params in this month
#
# - utilization           : 0.8
# - price decline         : 0.13
# - cu price              : 13
# - su price              : 8.8
# - nu price              : 0.05
#
# ### cloud units sold total
#
# - #cu        : 634k
# - #su        : 1,127k
# - #nu        : 45m
#
# ### per node production
#
# #### per node setup
#
# - USD investment cost per node: 2,351
#
# #### cloud units per node
#
# - #cu               : 17
# - #su               : 31
# - #nu               : 1,277
# - cost of 1 nu      : 0.01
# - passmark per cu   : 880
#
# #### resource units per node
#
# - cpr : 51
# - cru : 16
# - sru : 1,920
# - hru : 24k
# - mru : 64
#
# #### revenue per month per node based on simulation totals
#
# - rev compute month         : 163
# - rev storage month         : 193
# - rev network month         : 45
# - rev total month           : 402
#
# #### costs per month per node normalized over months
#
# - cost hardware month       : 39
# - cost rack month           : 60
# - cost power month          : 32
# - cost maintenance month    : 3.9
# - cost network month        : 12
#
# #### costs per month per node based on simulation totals
#
# - cost hardware month       : 39
# - cost rack month           : 59
# - cost power month          : 32
# - cost maintenance month    : 3.9
# - cost network month        : 12
# - cost total month          : 148
# - cost total month no hw    : 109
#
# ### per node per month
#
# - USD cultivated per node                                   :  402 USD
# - USD farmed per node                                       :  294 USD
# - USD burned per node                                       :  0 USD
# - USD monthly tft sold (rackspace/power/mgmt/net)           :  109 USD
# - USD monthly cost per node (rackspace/power/mgmt/net)      :  109 USD
# - USD profit for farmer per node (profit from token income) :  587 USD

# %%
md(simulation.markdown_reality_check(50))
# Out:
# ![](https://lh3.googleusercontent.com/ueuxCFqv1SvuR9HdR8GGz4-S8cJ8Z_do62mq7xaFVDgi31JCbPE5Hqjr7_ChvmXcgsrBuXZEYoX0Cv02iMe5yJfb_e-0-moQIrI=s1000)
# ## Some Totals for the simulation: (50 month mark)
#
# - nrnodes: 717412
# - nrtokens cultivated: 112,641,297
# - tft price: 2.54 USD
# - USD cultivated in that month: 286,108,894 USD
# - USD farmed in that month: 149,475,685 USD
#
# ### simulation params in this month
#
# - utilization           : 0.9
# - price decline         : 0.33
# - cu price              : 11
# - su price              : 7.5
# - nu price              : 0.05
#
# ### cloud units sold total
#
# - #cu        : 13m
# - #su        : 24m
# - #nu        : 824m
#
# ### per node production
#
# #### per node setup
#
# - USD investment cost per node: 2,351
#
# #### cloud units per node
#
# - #cu               : 20
# - #su               : 37
# - #nu               : 1,277
# - cost of 1 nu      : 0.01
# - passmark per cu   : 880
#
# #### resource units per node
#
# - cpr : 51
# - cru : 16
# - sru : 1,920
# - hru : 24k
# - mru : 64
#
# #### revenue per month per node based on simulation totals
#
# - rev compute month         : 158
# - rev storage month         : 188
# - rev network month         : 51
# - rev total month           : 398
#
# #### costs per month per node normalized over months
#
# - cost hardware month       : 39
# - cost rack month           : 60
# - cost power month          : 36
# - cost maintenance month    : 3.9
# - cost network month        : 14
#
# #### costs per month per node based on simulation totals
#
# - cost hardware month       : 39
# - cost rack month           : 59
# - cost power month          : 36
# - cost maintenance month    : 3.9
# - cost network month        : 14
# - cost total month          : 154
# - cost total month no hw    : 115
#
# ### per node per month
#
# - USD cultivated per node                                   :  398 USD
# - USD farmed per node                                       :  208 USD
# - USD burned per node                                       :  0 USD
# - USD monthly tft sold (rackspace/power/mgmt/net)           :  115 USD
# - USD monthly cost per node (rackspace/power/mgmt/net)      :  115 USD
# - USD profit for farmer per node (profit from token income) :  491 USD
